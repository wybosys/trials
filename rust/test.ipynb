// %%
:dep log
:dep env_logger

:env RUST_LOG=info
// Out:
// Set RUST_LOG=info (use :restart command to reload child process)

// %%
use log::info;

fn test() {
    env_logger::init();

    println!("sys: hello");
    info!("log: hello");
}

test();
// Out:
// sys: hello
// [2024-05-06T04:43:34Z INFO  ctx] log: hello

// %%
:restart
// Out:
// Child process restarted
